# %%
import sklearn as skl
import numpy as np
from ucimlrepo import fetch_ucirepo 
from sklearn.model_selection import train_test_split
  
# fetch dataset 
iris = fetch_ucirepo(id=53) 
  
# data (as pandas dataframes) 
X = iris.data.features 
y = iris.data.targets 
  
# metadata 
print(iris.metadata) 
  
# variable information 
print(iris.variables)

# %%
#SVM Algorithm
from sklearn import svm
X_train,X_test,y_train,y_test = train_test_split(X,np.ravel(y), test_size=0.85)
clf = svm.SVC(kernel='linear')
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)
print("Accuracy:", skl.metrics.accuracy_score(y_test,y_pred))
print(clf.predict)
# Out:
# Accuracy: 0.96875
# <bound method BaseSVC.predict of SVC(kernel='linear')>

# %%
import matplotlib.pyplot as plt
from sklearn.inspection import DecisionBoundaryDisplay

def make_meshgrid(x, y, h=.02):
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    return xx, yy

def plot_contours(ax, clf, xx, yy, **params):
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    out = ax.contourf(xx, yy, Z, **params)
    return out

# %%
#Decision Tree
from sklearn import tree
clf2 = tree.DecisionTreeClassifier()
clf2 = clf2.fit(X_train,y_train) 
y_pred2= clf2.predict(X_test)
print("Accuracy:",skl.metrics.accuracy_score(y_test,y_pred2))

tree.plot_tree(clf2)
# Out:
# Accuracy: 0.96875
# [Text(0.4, 0.875, 'x[2] <= 2.95\ngini = 0.649\nsamples = 22\nvalue = [9, 5, 8]'),
#  Text(0.2, 0.625, 'gini = 0.0\nsamples = 9\nvalue = [9, 0, 0]'),
#  Text(0.6, 0.625, 'x[2] <= 5.0\ngini = 0.473\nsamples = 13\nvalue = [0, 5, 8]'),
#  Text(0.4, 0.375, 'x[3] <= 1.7\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1]'),
#  Text(0.2, 0.125, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.6, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8, 0.375, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7]')]

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
clf3 = RandomForestClassifier(n_estimators = 1000)  
clf3.fit(X_train, y_train)
y_pred3 = clf3.predict(X_test)
print("Accuracy:",skl.metrics.accuracy_score(y_test,y_pred3))
# Out:
# Accuracy: 0.9609375
